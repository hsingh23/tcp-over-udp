# %%
#House Keeping
# %pylab inline
# %load_ext autoreload
# %autoreload 2
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3b5c6aed1b7f> in <module>()
#       3 get_ipython().magic(u'load_ext autoreload')
#       4 get_ipython().magic(u'autoreload 2')
# ----> 5 from parse_table import *
#       6 import numpy as np
#       7 import matplotlib.pyplot as plt
#
# ImportError: No module named parse_table
# Populating the interactive namespace from numpy and matplotlib

# %%
def load(file_name):
    with open(file_name, "r") as f:
        res = [ [float(i) for i in x.strip().split()] for x in f.readlines()]
    return res
def plot(data):
    plt.plot([x[1] for x in data], [x[0] for x in data])

# %%
t0 = load("trace_results/trace-10000_bytes-0")
t1 = load("trace_results/trace-10000_bytes-1")
t2 = load("trace_results/trace-10000_bytes-2")
c0 = load("cwnd_results/cwnd-10000_bytes-0")
c1 = load("cwnd_results/cwnd-10000_bytes-1")
c2 = load("cwnd_results/cwnd-10000_bytes-2")

# %%
plot(t0)

# %%
plot(t1)

# %%
plot(t2)

# %%
plot(c0)

# %%
plot(c1)

# %%
plot(c2)
